# %% [markdown]
# # Tally of Merchant Clusters

# %%
import pandas as pd
pd.options.display.max_colwidth = 200

# %%
merchant_details = pd.read_parquet("../data/tables/tbl_merchants.parquet").reset_index('merchant_abn')
merchant_clusters = pd.read_csv("../data/curated/merchant_clusters.csv")

display(merchant_details.head(3))
display(merchant_clusters.head(3))

print('# distinct abn in merchant_clusters:', len(merchant_clusters.merchant_abn.unique()))
print('# distinct abn in merchant_details:', len(merchant_details.merchant_abn.unique()))

new_merchant = sum([1 for abn in set(merchant_clusters.merchant_abn.unique()) if abn not in set(merchant_details.merchant_abn.unique())])
print('# new merchant appears in merchant_clusters:', new_merchant)
# Out:
#    merchant_abn                      name  \
# 0   10023283211             Felis Limited
# 1   10142254217  Arcu Ac Orci Corporation
# 2   10165489824          Nunc Sed Company
#
#                                                                                                                 tags
# 0  ((furniture, home furnishings and equipment shops, and manufacturers, except appliances), (e), (take rate: 0.18))
# 1                          ([cable, satellite, and otHer pay television and radio services], [b], [take rate: 4.22])
# 2                                            ([jewelry, watch, clock, and silverware shops], [b], [take rate: 4.40])
#    merchant_abn  label
# 0   10023283211      2
# 1   10342410215      2
# 2   10346855916      0
# # distinct abn in merchant_clusters: 4380
# # distinct abn in merchant_details: 4026
# # new merchant appears in merchant_clusters: 381

# %% [markdown]
# ## Extract the store categories

# %% [markdown]
# **Clean the tags**

# %%
# split the product description, revenue level and take rate
merchant_details[['prod_desc','revenue_level','take_rate']] = merchant_details.tags.str.split("\],|\), ",expand=True)
# only keep the product description
merchant_details = merchant_details.drop(columns=['tags','revenue_level','take_rate', 'name'])
# clean the strings
merchant_details.prod_desc = merchant_details.prod_desc.map(lambda x: x.lstrip(' ,([').rstrip(' )]').lower().replace('  ', ' '))
display(merchant_details.head())
# Out:
#    merchant_abn  \
# 0   10023283211
# 1   10142254217
# 2   10165489824
# 3   10187291046
# 4   10192359162
#
#                                                                                prod_desc
# 0  furniture, home furnishings and equipment shops, and manufacturers, except appliances
# 1                          cable, satellite, and other pay television and radio services
# 2                                            jewelry, watch, clock, and silverware shops
# 3                                                 watch, clock, and jewelry repair shops
# 4                             music shops - musical instruments, pianos, and sheet music

# %% [markdown]
# **We only have 25 distinct product descriptions**

# %%
display(merchant_details.describe())
display(set(merchant_details.prod_desc.values))
# Out:
#        merchant_abn
# count  4.026000e+03
# mean   5.446187e+10
# std    2.598939e+10
# min    1.002328e+10
# 25%    3.164828e+10
# 50%    5.432922e+10
# 75%    7.662773e+10
# max    9.999054e+10
# {'antique shops - sales, repairs, and restoration services',
#  'art dealers and galleries',
#  'artist supply and craft shops',
#  'bicycle shops - sales and service',
#  'books, periodicals, and newspapers',
#  'cable, satellite, and other pay television and radio services',
#  'computer programming , data processing, and integrated systems design services',
#  'computers, computer peripheral equipment, and software',
#  'digital goods: books, movies, music',
#  'equipment, tool, furniture, and appliance rent al and leasing',
#  'florists supplies, nursery stock, and flowers',
#  'furniture, home furnishings and equipment shops, and manufacturers, except appliances',
#  'gift, card, novelty, and souvenir shops',
#  'health and beauty spas',
#  'hobby, toy and game shops',
#  'jewelry, watch, clock, and silverware shops',
#  'lawn and garden supply outlets, including nurseries',
#  'motor vehicle supplies and new parts',
#  'music shops - musical instruments, pianos, and sheet music',
#  'opticians, optical goods, and eyeglasses',
#  'shoe shops',
#  'stationery, office supplies and printing and writing paper',
#  'telecom',
#  'tent and awning shops',
#  'watch, clock, and jewelry repair shops'}

# %% [markdown]
# ## Build the Tally!

# %% [markdown]
# **Inner join the product description and clustered labels**

# %%
prod_label_merged = merchant_clusters.merge(merchant_details, on='merchant_abn', how='inner')\
    .drop(columns=['merchant_abn'])
display(prod_label_merged.head(3))
# Out:
#    label  \
# 0      2
# 1      2
# 2      0
#
#                                                                                prod_desc
# 0  furniture, home furnishings and equipment shops, and manufacturers, except appliances
# 1                                 computers, computer peripheral equipment, and software
# 2                          equipment, tool, furniture, and appliance rent al and leasing

# %% [markdown]
# **Create an empty table**

# %%
my_tally = pd.DataFrame(index=set(merchant_details.prod_desc.unique()), columns=['cluster_' + str(cluster) for cluster in set(merchant_clusters.label.unique())]).fillna(0)
my_tally.index.name = 'product_description'
#display(my_tally.head(3))
# Out:
#                                                           cluster_0  \
# product_description
# florists supplies, nursery stock, and flowers                     0
# bicycle shops - sales and service                                 0
# antique shops - sales, repairs, and restoration services          0
#
#                                                           cluster_1  cluster_2
# product_description
# florists supplies, nursery stock, and flowers                     0          0
# bicycle shops - sales and service                                 0          0
# antique shops - sales, repairs, and restoration services          0          0

# %% [markdown]
# **Fill the frequency in!**

# %%
for cluster in set(merchant_clusters.label.unique()):
    for prod_desc in prod_label_merged[prod_label_merged.label == cluster].prod_desc.values:
        my_tally.loc[prod_desc, 'cluster_'+str(cluster)] += 1

my_tally['sum'] = my_tally.sum(axis=1)    
display(my_tally)
# Out:
#                                                                                        cluster_0  \
# product_description
# florists supplies, nursery stock, and flowers                                                106
# bicycle shops - sales and service                                                             97
# antique shops - sales, repairs, and restoration services                                      85
# tent and awning shops                                                                         74
# stationery, office supplies and printing and writing paper                                   109
# watch, clock, and jewelry repair shops                                                        88
# shoe shops                                                                                   103
# lawn and garden supply outlets, including nurseries                                           85
# gift, card, novelty, and souvenir shops                                                       65
# computer programming , data processing, and integrated systems design services               111
# motor vehicle supplies and new parts                                                          85
# hobby, toy and game shops                                                                     87
# music shops - musical instruments, pianos, and sheet music                                   119
# equipment, tool, furniture, and appliance rent al and leasing                                 91
# jewelry, watch, clock, and silverware shops                                                   73
# opticians, optical goods, and eyeglasses                                                      71
# health and beauty spas                                                                        97
# telecom                                                                                       91
# computers, computer peripheral equipment, and software                                       100
# books, periodicals, and newspapers                                                            96
# furniture, home furnishings and equipment shops, and manufacturers, except appliances        101
# digital goods: books, movies, music                                                           66
# art dealers and galleries                                                                     80
# cable, satellite, and other pay television and radio services                                 64
# artist supply and craft shops                                                                116
#
#                                                                                        cluster_1  \
# product_description
# florists supplies, nursery stock, and flowers                                                 12
# bicycle shops - sales and service                                                             11
# antique shops - sales, repairs, and restoration services                                       7
# tent and awning shops                                                                         43
# stationery, office supplies and printing and writing paper                                     3
# watch, clock, and jewelry repair shops                                                        29
# shoe shops                                                                                    17
# lawn and garden supply outlets, including nurseries                                           14
# gift, card, novelty, and souvenir shops                                                       47
# computer programming , data processing, and integrated systems design services                19
# motor vehicle supplies and new parts                                                          14
# hobby, toy and game shops                                                                     12
# music shops - musical instruments, pianos, and sheet music                                     9
# equipment, tool, furniture, and appliance rent al and leasing                                  2
# jewelry, watch, clock, and silverware shops                                                    0
# opticians, optical goods, and eyeglasses                                                      27
# health and beauty spas                                                                         7
# telecom                                                                                        3
# computers, computer peripheral equipment, and software                                        18
# books, periodicals, and newspapers                                                            10
# furniture, home furnishings and equipment shops, and manufacturers, except appliances         16
# digital goods: books, movies, music                                                           55
# art dealers and galleries                                                                      2
# cable, satellite, and other pay television and radio services                                 46
# artist supply and craft shops                                                                 10
#
#                                                                                        cluster_2  \
# product_description
# florists supplies, nursery stock, and flowers                                                 62
# bicycle shops - sales and service                                                             62
# antique shops - sales, repairs, and restoration services                                      21
# tent and awning shops                                                                         61
# stationery, office supplies and printing and writing paper                                    49
# watch, clock, and jewelry repair shops                                                        53
# shoe shops                                                                                    65
# lawn and garden supply outlets, including nurseries                                           54
# gift, card, novelty, and souvenir shops                                                       70
# computer programming , data processing, and integrated systems design services                61
# motor vehicle supplies and new parts                                                          52
# hobby, toy and game shops                                                                     43
# music shops - musical instruments, pianos, and sheet music                                    39
# equipment, tool, furniture, and appliance rent al and leasing                                 41
# jewelry, watch, clock, and silverware shops                                                    8
# opticians, optical goods, and eyeglasses                                                      53
# health and beauty spas                                                                        60
# telecom                                                                                       31
# computers, computer peripheral equipment, and software                                        63
# books, periodicals, and newspapers                                                            58
# furniture, home furnishings and equipment shops, and manufacturers, except appliances         65
# digital goods: books, movies, music                                                           74
# art dealers and galleries                                                                     29
# cable, satellite, and other pay television and radio services                                 65
# artist supply and craft shops                                                                 67
#
#                                                                                        sum
# product_description
# florists supplies, nursery stock, and flowers                                          180
# bicycle shops - sales and service                                                      170
# antique shops - sales, repairs, and restoration services                               113
# tent and awning shops                                                                  178
# stationery, office supplies and printing and writing paper                             161
# watch, clock, and jewelry repair shops                                                 170
# shoe shops                                                                             185
# lawn and garden supply outlets, including nurseries                                    153
# gift, card, novelty, and souvenir shops                                                182
# computer programming , data processing, and integrated systems design services         191
# motor vehicle supplies and new parts                                                   151
# hobby, toy and game shops                                                              142
# music shops - musical instruments, pianos, and sheet music                             167
# equipment, tool, furniture, and appliance rent al and leasing                          134
# jewelry, watch, clock, and silverware shops                                             81
# opticians, optical goods, and eyeglasses                                               151
# health and beauty spas                                                                 164
# telecom                                                                                125
# computers, computer peripheral equipment, and software                                 181
# books, periodicals, and newspapers                                                     164
# furniture, home furnishings and equipment shops, and manufacturers, except appliances  182
# digital goods: books, movies, music                                                    195
# art dealers and galleries                                                              111
# cable, satellite, and other pay television and radio services                          175
# artist supply and craft shops                                                          193

# %%
my_tally.sum()
# Out:
# cluster_0    2260
# cluster_1     433
# cluster_2    1306
# dtype: int64

# %%
for i in range(3):
    display(my_tally.sort_values([f'cluster_{i}'], ascending=False)[f'cluster_{i}'].head(5))
# Out:
# product_description
# music shops - musical instruments, pianos, and sheet music                        119
# artist supply and craft shops                                                     116
# computer programming , data processing, and integrated systems design services    111
# stationery, office supplies and printing and writing paper                        109
# florists supplies, nursery stock, and flowers                                     106
# Name: cluster_0, dtype: int64
# product_description
# digital goods: books, movies, music                              55
# gift, card, novelty, and souvenir shops                          47
# cable, satellite, and other pay television and radio services    46
# tent and awning shops                                            43
# watch, clock, and jewelry repair shops                           29
# Name: cluster_1, dtype: int64
# product_description
# digital goods: books, movies, music                                                      74
# gift, card, novelty, and souvenir shops                                                  70
# artist supply and craft shops                                                            67
# cable, satellite, and other pay television and radio services                            65
# furniture, home furnishings and equipment shops, and manufacturers, except appliances    65
# Name: cluster_2, dtype: int64

# %% [markdown]
# ## Take a look at the percentages

# %% [markdown]
# **By product descriptions**

# %%
byProd_tally = my_tally.iloc[:,0:3].copy()
for col in byProd_tally.columns:
    byProd_tally[col] = byProd_tally[col]/my_tally['sum']

# %%
byProd_tally
# Out:
#                                                                                        cluster_0  \
# product_description
# florists supplies, nursery stock, and flowers                                           0.588889
# bicycle shops - sales and service                                                       0.570588
# antique shops - sales, repairs, and restoration services                                0.752212
# tent and awning shops                                                                   0.415730
# stationery, office supplies and printing and writing paper                              0.677019
# watch, clock, and jewelry repair shops                                                  0.517647
# shoe shops                                                                              0.556757
# lawn and garden supply outlets, including nurseries                                     0.555556
# gift, card, novelty, and souvenir shops                                                 0.357143
# computer programming , data processing, and integrated systems design services          0.581152
# motor vehicle supplies and new parts                                                    0.562914
# hobby, toy and game shops                                                               0.612676
# music shops - musical instruments, pianos, and sheet music                              0.712575
# equipment, tool, furniture, and appliance rent al and leasing                           0.679104
# jewelry, watch, clock, and silverware shops                                             0.901235
# opticians, optical goods, and eyeglasses                                                0.470199
# health and beauty spas                                                                  0.591463
# telecom                                                                                 0.728000
# computers, computer peripheral equipment, and software                                  0.552486
# books, periodicals, and newspapers                                                      0.585366
# furniture, home furnishings and equipment shops, and manufacturers, except appliances   0.554945
# digital goods: books, movies, music                                                     0.338462
# art dealers and galleries                                                               0.720721
# cable, satellite, and other pay television and radio services                           0.365714
# artist supply and craft shops                                                           0.601036
#
#                                                                                        cluster_1  \
# product_description
# florists supplies, nursery stock, and flowers                                           0.066667
# bicycle shops - sales and service                                                       0.064706
# antique shops - sales, repairs, and restoration services                                0.061947
# tent and awning shops                                                                   0.241573
# stationery, office supplies and printing and writing paper                              0.018634
# watch, clock, and jewelry repair shops                                                  0.170588
# shoe shops                                                                              0.091892
# lawn and garden supply outlets, including nurseries                                     0.091503
# gift, card, novelty, and souvenir shops                                                 0.258242
# computer programming , data processing, and integrated systems design services          0.099476
# motor vehicle supplies and new parts                                                    0.092715
# hobby, toy and game shops                                                               0.084507
# music shops - musical instruments, pianos, and sheet music                              0.053892
# equipment, tool, furniture, and appliance rent al and leasing                           0.014925
# jewelry, watch, clock, and silverware shops                                             0.000000
# opticians, optical goods, and eyeglasses                                                0.178808
# health and beauty spas                                                                  0.042683
# telecom                                                                                 0.024000
# computers, computer peripheral equipment, and software                                  0.099448
# books, periodicals, and newspapers                                                      0.060976
# furniture, home furnishings and equipment shops, and manufacturers, except appliances   0.087912
# digital goods: books, movies, music                                                     0.282051
# art dealers and galleries                                                               0.018018
# cable, satellite, and other pay television and radio services                           0.262857
# artist supply and craft shops                                                           0.051813
#
#                                                                                        cluster_2
# product_description
# florists supplies, nursery stock, and flowers                                           0.344444
# bicycle shops - sales and service                                                       0.364706
# antique shops - sales, repairs, and restoration services                                0.185841
# tent and awning shops                                                                   0.342697
# stationery, office supplies and printing and writing paper                              0.304348
# watch, clock, and jewelry repair shops                                                  0.311765
# shoe shops                                                                              0.351351
# lawn and garden supply outlets, including nurseries                                     0.352941
# gift, card, novelty, and souvenir shops                                                 0.384615
# computer programming , data processing, and integrated systems design services          0.319372
# motor vehicle supplies and new parts                                                    0.344371
# hobby, toy and game shops                                                               0.302817
# music shops - musical instruments, pianos, and sheet music                              0.233533
# equipment, tool, furniture, and appliance rent al and leasing                           0.305970
# jewelry, watch, clock, and silverware shops                                             0.098765
# opticians, optical goods, and eyeglasses                                                0.350993
# health and beauty spas                                                                  0.365854
# telecom                                                                                 0.248000
# computers, computer peripheral equipment, and software                                  0.348066
# books, periodicals, and newspapers                                                      0.353659
# furniture, home furnishings and equipment shops, and manufacturers, except appliances   0.357143
# digital goods: books, movies, music                                                     0.379487
# art dealers and galleries                                                               0.261261
# cable, satellite, and other pay television and radio services                           0.371429
# artist supply and craft shops                                                           0.347150

# %%
for i in range(3):
    display(byProd_tally.sort_values([f'cluster_{i}'], ascending=False)[f'cluster_{i}'].head(5))
# Out:
# product_description
# jewelry, watch, clock, and silverware shops                   0.901235
# antique shops - sales, repairs, and restoration services      0.752212
# telecom                                                       0.728000
# art dealers and galleries                                     0.720721
# music shops - musical instruments, pianos, and sheet music    0.712575
# Name: cluster_0, dtype: float64
# product_description
# digital goods: books, movies, music                              0.282051
# cable, satellite, and other pay television and radio services    0.262857
# gift, card, novelty, and souvenir shops                          0.258242
# tent and awning shops                                            0.241573
# opticians, optical goods, and eyeglasses                         0.178808
# Name: cluster_1, dtype: float64
# product_description
# gift, card, novelty, and souvenir shops                          0.384615
# digital goods: books, movies, music                              0.379487
# cable, satellite, and other pay television and radio services    0.371429
# health and beauty spas                                           0.365854
# bicycle shops - sales and service                                0.364706
# Name: cluster_2, dtype: float64

# %% [markdown]
# **By cluster labels**

# %%
byCluster_tally = my_tally.iloc[:,0:3].copy()
for col in byCluster_tally.columns:
    byCluster_tally[col] = byCluster_tally[col]/my_tally[col].sum()

# %%
byCluster_tally
# Out:
#                                                                                        cluster_0  \
# product_description
# florists supplies, nursery stock, and flowers                                           0.046903
# bicycle shops - sales and service                                                       0.042920
# antique shops - sales, repairs, and restoration services                                0.037611
# tent and awning shops                                                                   0.032743
# stationery, office supplies and printing and writing paper                              0.048230
# watch, clock, and jewelry repair shops                                                  0.038938
# shoe shops                                                                              0.045575
# lawn and garden supply outlets, including nurseries                                     0.037611
# gift, card, novelty, and souvenir shops                                                 0.028761
# computer programming , data processing, and integrated systems design services          0.049115
# motor vehicle supplies and new parts                                                    0.037611
# hobby, toy and game shops                                                               0.038496
# music shops - musical instruments, pianos, and sheet music                              0.052655
# equipment, tool, furniture, and appliance rent al and leasing                           0.040265
# jewelry, watch, clock, and silverware shops                                             0.032301
# opticians, optical goods, and eyeglasses                                                0.031416
# health and beauty spas                                                                  0.042920
# telecom                                                                                 0.040265
# computers, computer peripheral equipment, and software                                  0.044248
# books, periodicals, and newspapers                                                      0.042478
# furniture, home furnishings and equipment shops, and manufacturers, except appliances   0.044690
# digital goods: books, movies, music                                                     0.029204
# art dealers and galleries                                                               0.035398
# cable, satellite, and other pay television and radio services                           0.028319
# artist supply and craft shops                                                           0.051327
#
#                                                                                        cluster_1  \
# product_description
# florists supplies, nursery stock, and flowers                                           0.027714
# bicycle shops - sales and service                                                       0.025404
# antique shops - sales, repairs, and restoration services                                0.016166
# tent and awning shops                                                                   0.099307
# stationery, office supplies and printing and writing paper                              0.006928
# watch, clock, and jewelry repair shops                                                  0.066975
# shoe shops                                                                              0.039261
# lawn and garden supply outlets, including nurseries                                     0.032333
# gift, card, novelty, and souvenir shops                                                 0.108545
# computer programming , data processing, and integrated systems design services          0.043880
# motor vehicle supplies and new parts                                                    0.032333
# hobby, toy and game shops                                                               0.027714
# music shops - musical instruments, pianos, and sheet music                              0.020785
# equipment, tool, furniture, and appliance rent al and leasing                           0.004619
# jewelry, watch, clock, and silverware shops                                             0.000000
# opticians, optical goods, and eyeglasses                                                0.062356
# health and beauty spas                                                                  0.016166
# telecom                                                                                 0.006928
# computers, computer peripheral equipment, and software                                  0.041570
# books, periodicals, and newspapers                                                      0.023095
# furniture, home furnishings and equipment shops, and manufacturers, except appliances   0.036952
# digital goods: books, movies, music                                                     0.127021
# art dealers and galleries                                                               0.004619
# cable, satellite, and other pay television and radio services                           0.106236
# artist supply and craft shops                                                           0.023095
#
#                                                                                        cluster_2
# product_description
# florists supplies, nursery stock, and flowers                                           0.047473
# bicycle shops - sales and service                                                       0.047473
# antique shops - sales, repairs, and restoration services                                0.016080
# tent and awning shops                                                                   0.046708
# stationery, office supplies and printing and writing paper                              0.037519
# watch, clock, and jewelry repair shops                                                  0.040582
# shoe shops                                                                              0.049770
# lawn and garden supply outlets, including nurseries                                     0.041348
# gift, card, novelty, and souvenir shops                                                 0.053599
# computer programming , data processing, and integrated systems design services          0.046708
# motor vehicle supplies and new parts                                                    0.039816
# hobby, toy and game shops                                                               0.032925
# music shops - musical instruments, pianos, and sheet music                              0.029862
# equipment, tool, furniture, and appliance rent al and leasing                           0.031394
# jewelry, watch, clock, and silverware shops                                             0.006126
# opticians, optical goods, and eyeglasses                                                0.040582
# health and beauty spas                                                                  0.045942
# telecom                                                                                 0.023737
# computers, computer peripheral equipment, and software                                  0.048239
# books, periodicals, and newspapers                                                      0.044410
# furniture, home furnishings and equipment shops, and manufacturers, except appliances   0.049770
# digital goods: books, movies, music                                                     0.056662
# art dealers and galleries                                                               0.022205
# cable, satellite, and other pay television and radio services                           0.049770
# artist supply and craft shops                                                           0.051302

# %%
for i in range(3):
    display(byCluster_tally.sort_values([f'cluster_{i}'], ascending=False)[f'cluster_{i}'].head(5))
# Out:
# product_description
# music shops - musical instruments, pianos, and sheet music                        0.052655
# artist supply and craft shops                                                     0.051327
# computer programming , data processing, and integrated systems design services    0.049115
# stationery, office supplies and printing and writing paper                        0.048230
# florists supplies, nursery stock, and flowers                                     0.046903
# Name: cluster_0, dtype: float64
# product_description
# digital goods: books, movies, music                              0.127021
# gift, card, novelty, and souvenir shops                          0.108545
# cable, satellite, and other pay television and radio services    0.106236
# tent and awning shops                                            0.099307
# watch, clock, and jewelry repair shops                           0.066975
# Name: cluster_1, dtype: float64
# product_description
# digital goods: books, movies, music                                                      0.056662
# gift, card, novelty, and souvenir shops                                                  0.053599
# artist supply and craft shops                                                            0.051302
# cable, satellite, and other pay television and radio services                            0.049770
# furniture, home furnishings and equipment shops, and manufacturers, except appliances    0.049770
# Name: cluster_2, dtype: float64
# 22/09/28 06:10:29 WARN HeartbeatReceiver: Removing executor driver with no recent heartbeats: 1065669 ms exceeds timeout 120000 ms
# 22/09/28 06:10:29 WARN SparkContext: Killing executors is not supported by current scheduler.

# %% [markdown]
# ## Save to CSV

# %%
my_tally.to_csv('../data/curated/tally_merchant_cluster_prod_desc.csv')
